# %% [markdown]
# # Tipos de Datos y Operaciones Básicas
#
# ## 1. Los conceptos básicos
# Experimente de forma interactiva con las operaciones de tipo comunes que se encuentran en las diversas tablas de operaciones en esta parte del libro. Para comenzar, abra el intérprete interactivo de Python (un REPL de su elección), escriba cada una de las siguientes expresiones e intente explicar qué sucede en cada caso. Tenga en cuenta que el punto y coma en algunas de estas se utiliza como separador de declaraciones, para exprimir múltiples declaraciones en una sola línea: por ejemplo, X=1;X asigna y luego imprime una variable (más sobre la sintaxis de las declaraciones en la siguiente parte del libro). Recuerde también que una coma entre expresiones generalmente construye una tupla, incluso si no hay paréntesis cerrados: X,Y,Z es una tupla de tres elementos, que Python le devuelve entre paréntesis.

# %%
2 ** 16
2 / 5, 2 / 5.0
'hack' + 'code'
S = 'Python'
'grok ' + S
S * 5
S[0], S[:0], S[1:]
how = 'fun'
'coding %s is %s!' % (S, how)
'coding {} is {}!'.format(S, how)
f'coding {S} is {how}!'
('x',)[0]
('x', 'y')[1]
L = [1, 2, 3] + [4, 5, 6]
L, L[:], L[:0], L[−2], L[−2:]
([1, 2, 3] + [4, 5, 6])[2:4]
[L[2], L[3]]
L.reverse(); L
L.sort(); L
L.index(4)
{'a': 1, 'b': 2}['b']
D = {'x': 1, 'y': 2, 'z': 3}
D['w'] = 0
D['x'] + D['w']
D[(1, 2, 3)] = 4
list(D.keys()), list(D.values()), (1, 2, 3) in D
[[]], ["", [], (), {}, None]

# %% [markdown]
# ## 2. Indexación y desglosamiento
# En el indicador interactivo, defina una lista llamada L que contenga cuatro cadenas o números (por ejemplo, L=[0, 1, 2, 3]). Luego, experimente con los siguientes casos límite. Es posible que nunca vea estos casos en programas reales (¡especialmente no de las formas extrañas en que pueden aparecer aquí!), pero están destinados a hacerle pensar en el modelo subyacente, y algunos pueden ser útiles en formas menos artificiales; desglosar fuera de los límites puede ayudar, por ejemplo, si una secuencia no es tan larga como espera:
# a. ¿Qué sucede cuando intenta indexar fuera de los límites (por ejemplo, L[4])?
# b. ¿Qué pasa con el desglosamiento fuera de los límites (por ejemplo, L[-1000:100])?
# c. Finalmente, ¿cómo lo maneja Python si intenta extraer una secuencia a la inversa, con el límite inferior mayor que el límite superior (por ejemplo, L[3:1])? Pista: intente asignar a este desglose (L[3:1]=['?']) y vea dónde se coloca el valor. ¿Cree que este puede ser el mismo fenómeno que vio al desglosar fuera de los límites?

# %% [markdown]
# ## 3. Indexación, desglosamiento y del
# Defina otra lista L con cuatro elementos y asigne una lista vacía a uno de sus desplazamientos (por ejemplo, L[2]=[]). ¿Qué pasa? Luego, asigne una lista vacía a un desglose (L[2:3]=[]). ¿Qué pasa ahora? Recuerde que la asignación de desglose elimina el desglose e inserta el nuevo valor donde solía estar.
# La declaración del elimina desplazamientos, claves, atributos y nombres. Úselo en su lista para eliminar un elemento (por ejemplo, del L[0]). ¿Qué sucede si elimina un desglose completo (del L[1:])? ¿Qué sucede cuando asigna una no secuencia a un desglose (L[1:2]=1)?

# %% [markdown]
# ## 4. Asignación de tuplas
# Escriba las siguientes líneas:
# ¿Qué cree que les está pasando a X e Y cuando escribe esta secuencia?

# %%
X = 'code'
Y = 'hack'
X, Y = Y, X

# %% [markdown]
# ## 5. Claves de diccionario
# Considere los siguientes fragmentos de código (1)
# Ha aprendido que no se accede a los diccionarios por desplazamientos, entonces, ¿qué está pasando aquí? ¿Lo siguiente aclara algo sobre el tema? (Pista: ¿las cadenas, los enteros y las tuplas comparten qué categoría de tipo?) (2)

# %%
D = {}
D[1] = 'a'
D[2] = 'b'

D[(1, 2, 3)] = 'c'
D

# %% [markdown]
# ## 6. Indexación de diccionarios
# Cree un diccionario llamado D con tres entradas, para las claves 'a', 'b' y 'c'. ¿Qué sucede si intenta indexar una clave inexistente (D['d'])? ¿Qué hace Python si intenta asignar a una clave inexistente 'd' (por ejemplo, D['d']='hack')? ¿Cómo se compara esto con las asignaciones y referencias fuera de los límites para las listas? ¿Suena esto como la regla para los nombres de variables?

# %% [markdown]
# ## 7. Operaciones genéricas
# Ejecute pruebas interactivas para responder a las siguientes preguntas:
# a. ¿Qué sucede cuando intenta utilizar el operador + en tipos diferentes/mixtos (por ejemplo, cadena + lista, lista + tupla)?
# b. ¿Funciona + cuando uno de los operandos es un diccionario?
# c. ¿Funciona el método append tanto para listas como para cadenas? ¿Qué tal usar el método keys en listas? (Pista: ¿qué asume append sobre su objeto sujeto?)
# d. Finalmente, ¿qué tipo de objeto obtiene cuando desglosa o concatena de dos listas o dos cadenas?

# %% [markdown]
# ## 8. Indexación de cadenas
# Defina una cadena S de cuatro caracteres: S = 'hack'. Luego escriba la siguiente expresión: S[0][0][0][0][0]. ¿Alguna pista de lo que está sucediendo esta vez? (Pista: recuerde que una cadena es una colección de caracteres, pero los caracteres de Python son cadenas de un solo carácter). ¿Funciona esta expresión de indexación si la aplica a una lista como ['h', 'a', 'c', 'k']? ¿Por qué?

# %% [markdown]
# ## 9. Tipos inmutables
# Defina una cadena S de cuatro caracteres nuevamente: S = 'hack'. Escriba una asignación que cambie la cadena a 'heck', utilizando solo desglosamiento y concatenación. ¿Podría realizar la misma operación utilizando solo indexación y concatenación? ¿Qué tal la asignación de índices?

# %% [markdown]
# ## 10. Anidamiento
# Escriba una estructura de datos que represente su información personal: nombre (primer, segundo, apellido), edad, trabajo, dirección, dirección de correo electrónico y número de teléfono. Puede construir la estructura de datos con cualquier combinación de tipos de objetos integrados que desee (listas, tuplas, diccionarios, cadenas, números). Luego, acceda a los componentes individuales de sus estructuras de datos mediante indexación. ¿Tienen más sentido algunas estructuras que otras para este objeto?

# %% [markdown]
# ## 11. Archivos
# Escriba un script que cree un nuevo archivo de salida llamado myfile.txt y escriba la cadena 'Hello file world!' en él. Luego escriba otro script que abra myfile.txt y lea e imprima su contenido. Ejecute sus dos scripts desde la línea de comandos del sistema (u otra herramienta de inicio de scripts disponible para usted). ¿Aparece el nuevo archivo en el directorio donde ejecutó sus scripts? ¿Qué pasa si agrega una ruta de directorio diferente al nombre de archivo pasado a open? Nota: los métodos de escritura de archivos no agregan caracteres de nueva línea a sus cadenas; agregue un \n explícito al final de la cadena si desea terminar completamente la línea en el archivo.

# %% [markdown]
# ### Preguntas de Repaso
# 1. ¿Cómo se puede determinar qué tan grande es una tupla? ¿Por qué esta herramienta se encuentra donde está?
# 2. Escriba una expresión que cambie el primer elemento de una tupla. (4, 5, 6) debería convertirse en (1, 5, 6) en el proceso.
# 3. ¿Cuál es el valor predeterminado para el argumento del modo de procesamiento en una llamada de apertura de archivo?
# 4. ¿Qué módulo podría usar para almacenar objetos de Python en un archivo sin convertirlos a cadenas usted mismo?
# 5. ¿Cómo podría hacer para copiar todas las partes de una estructura anidada a la vez?
# 6. ¿Cuándo considera Python que un objeto es verdadero?
